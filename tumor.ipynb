# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '1'

# %%
import fnmatch
train = []
tes = []
val = []

for root,dirs,files in os.walk('./3fold_out4/train'):
    if files:
        lst = os.listdir(root)
        png = fnmatch.filter(lst,'*.png')
        if png:
            for i in png:
                train.append((root+'/'+i, int(i[3])-1))
for root,dirs,files in os.walk('./3fold_out4/test'):
      if files:
        lst = os.listdir(root)
        png = fnmatch.filter(lst,'*.png')
        if png:
            for i in png:
                tes.append((root+'/'+i, int(i[3])-1))
for root,dirs,files in os.walk('./3fold_out4/val'):
      if files:
        lst = os.listdir(root)
        png = fnmatch.filter(lst,'*.png')
        if png:
            for i in png:
                val.append((root+'/'+i, int(i[3])-1))

# %%
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
cout = [0]*4
for i in val:
    if i[1] == 0:
        cout[0]+=1
    if i[1] == 1:
        cout[1]+=1
    if i[1] == 2:
        cout[2]+=1
    if i[1] == 3:
        cout[3]+=1
print(cout,sum(cout))
# Out:
# [49, 20, 65, 44] 178

# %%
trn = train + tes
trn, _ = train_test_split(trn, test_size = 0.667)
test = val

# %%
class MyDataset(Dataset):
    def __init__(self, image_path, transform = None):
        self.image_list = image_path
        self.len = len(self.image_list)
        self.transform = transform
    def __getitem__(self, index):
        fn, label = self.image_list[index]
        img = Image.open(fn)
        label = np.array(label,dtype = np.float64)
        if self.transform is not None:
            img = self.transform(img) 
        return img, label
    def __len__(self):
        return self.len

Transform = transforms.Compose([
    transforms.RandomRotation(degrees=15),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    #transforms.CenterCrop(224),
    transforms.Resize(128),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
    ])
Lable_trasfrom = transforms.Compose([
    transforms.ToTensor()
    ])

# %%
train_data = MyDataset(trn, transform = Transform)
test_data = MyDataset(test, transform = Transform)
train_loader = DataLoader(dataset=train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=32, shuffle=False)

# %%
for i,(data,label) in enumerate(train_loader):
    print(data.shape)
# Out:
# torch.Size([32, 3, 128, 128])
# torch.Size([32, 3, 128, 128])
# torch.Size([32, 3, 128, 128])
# torch.Size([7, 3, 128, 128])

# %%
import torchvision.models as models
from torch import nn,optim

# %%
my_resnet = models.resnet18(pretrained=True)

# %%
my_resnet.fc = nn.Sequential(
    nn.Linear(512, 128),
    nn.ReLU(),
    nn.Dropout(0.8),
    nn.Linear(128,4),
    nn.LogSoftmax(dim=1)
)
'''
my_resnet.classifier = nn.Sequential(
    nn.Linear(1024, 128),
    nn.ReLU(),
    nn.Dropout(0.6),
    nn.Linear(128,5),
    nn.LogSoftmax(dim=1)
)'''
# Out:
# '\nmy_resnet.classifier = nn.Sequential(\n    nn.Linear(1024, 128),\n    nn.ReLU(),\n    nn.Dropout(0.6),\n    nn.Linear(128,5),\n    nn.LogSoftmax(dim=1)\n)'

# %%
my_resnet = my_resnet.to('cuda:0')

# %%
#loss_func = FocalLoss()
#loss_func = NPairLoss()
loss_func = nn.NLLLoss()
lr = 1e-3
#optimizer = optim.Adam(my_resnet.parameters(), lr=lr)
#optimizer = optim.Adam(my_resnet.parameters(), lr=lr)
optimizer = optim.SGD(my_resnet.parameters(),
                                lr=lr,
                                momentum=0.9,
                                weight_decay=1e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=200, gamma=0.1, last_epoch=-1)

# %%
import time

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0
best_each = ''

b = 0.3
best_loss = 100.0

# %%
for epoch in range(100):
    epoch_start = time.time()
    print("Epoch: {}/{}".format(epoch+1, 100))
    my_resnet.train()
    train_loss = 0.0
    valid_loss = 0.0
    train_acc = 0.0
    valid_acc = 0.0
    for i,(data,label) in enumerate(train_loader):
        data = data.to(device)
        label = label.to(device)
        label = label.long()
        optimizer.zero_grad()
        outputs = my_resnet(data)
        loss = loss_func(outputs,label)
        #loss = abs(loss-b) + b
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data.size(0)
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(label.data.view_as(predictions))
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
        train_acc += acc.item() * data.size(0)
    with torch.no_grad():
        my_resnet.eval()
        correct = list(0. for i in range(4))
        total = list(0. for i in range(4))
        #correct = list(0. for i in range(2))
        #total = list(0. for i in range(2))
        for j, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            labels = labels.long()

            outputs = my_resnet(inputs)

            loss = loss_func(outputs, labels)
            #loss = abs(loss-b) + b
            valid_loss += loss.item() * inputs.size(0)
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            valid_acc += acc.item() * inputs.size(0)
            res = predictions == labels
            for label_idx in range(len(labels)):
                label_single = labels[label_idx]
                correct[label_single] += res[label_idx].item()
                total[label_single] += 1

    scheduler.step()
    avg_train_loss = train_loss/len(trn)
    avg_train_acc = train_acc/len(trn)

    avg_valid_loss = valid_loss/len(test)
    avg_valid_acc = valid_acc/len(test)

    acc_str = 'Accuracy: %f'%(sum(correct)/sum(total))

    for acc_idx in range(4):
    #for acc_idx in range(2):
        try:
            acc = correct[acc_idx]/total[acc_idx]
        except:
            acc = 0
        finally:
            acc_str += ' classID:%d acc:%f '%(acc_idx+1, acc)

    history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
    if best_acc <= avg_valid_acc:
        best_acc = avg_valid_acc
        best_epoch = epoch + 1
        best_each = acc_str

    epoch_end = time.time()

    print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))
    print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))
    print(acc_str)#print("Best Acc's each class acc:",best_each)
print("Best Acc's each class acc:",best_each)
# Out:
# Epoch: 1/100
# Epoch: 001, Training: Loss: 1.5910, Accuracy: 28.1553%,
# 		Validation: Loss: 1.4190, Accuracy: 27.5281%, Time: 1.2378s
# Best Accuracy for validation : 0.2753 at epoch 001
# Accuracy: 0.275281 classID:1 acc:0.775510  classID:2 acc:0.050000  classID:3 acc:0.000000  classID:4 acc:0.227273
# Epoch: 2/100
# Epoch: 002, Training: Loss: 1.5390, Accuracy: 29.1262%,
# 		Validation: Loss: 1.4028, Accuracy: 26.4045%, Time: 0.3904s
# Best Accuracy for validation : 0.2753 at epoch 001
# Accuracy: 0.264045 classID:1 acc:0.877551  classID:2 acc:0.000000  classID:3 acc:0.015385  classID:4 acc:0.068182
# Epoch: 3/100
# Epoch: 003, Training: Loss: 1.4299, Accuracy: 32.0388%,
# 		Validation: Loss: 1.3680, Accuracy: 31.4607%, Time: 0.3842s
# Best Accuracy for validation : 0.3146 at epoch 003
# Accuracy: 0.314607 classID:1 acc:0.938776  classID:2 acc:0.000000  classID:3 acc:0.138462  classID:4 acc:0.022727
# Epoch: 4/100
# Epoch: 004, Training: Loss: 1.4794, Accuracy: 27.1845%,
# 		Validation: Loss: 1.3622, Accuracy: 33.1461%, Time: 0.3860s
# Best Accuracy for validation : 0.3315 at epoch 004
# Accuracy: 0.331461 classID:1 acc:0.979592  classID:2 acc:0.050000  classID:3 acc:0.153846  classID:4 acc:0.000000
# Epoch: 5/100
# Epoch: 005, Training: Loss: 1.3700, Accuracy: 40.7767%,
# 		Validation: Loss: 1.3412, Accuracy: 36.5169%, Time: 0.3837s
# Best Accuracy for validation : 0.3652 at epoch 005
# Accuracy: 0.365169 classID:1 acc:0.897959  classID:2 acc:0.100000  classID:3 acc:0.292308  classID:4 acc:0.000000
# Epoch: 6/100
# Epoch: 006, Training: Loss: 1.2752, Accuracy: 37.8641%,
# 		Validation: Loss: 1.3201, Accuracy: 40.4494%, Time: 0.3835s
# Best Accuracy for validation : 0.4045 at epoch 006
# Accuracy: 0.404494 classID:1 acc:0.775510  classID:2 acc:0.250000  classID:3 acc:0.446154  classID:4 acc:0.000000
# Epoch: 7/100
# Epoch: 007, Training: Loss: 1.2872, Accuracy: 39.8058%,
# 		Validation: Loss: 1.2818, Accuracy: 43.2584%, Time: 0.3836s
# Best Accuracy for validation : 0.4326 at epoch 007
# Accuracy: 0.432584 classID:1 acc:0.857143  classID:2 acc:0.300000  classID:3 acc:0.430769  classID:4 acc:0.022727
# Epoch: 8/100
# Epoch: 008, Training: Loss: 1.1992, Accuracy: 44.6602%,
# 		Validation: Loss: 1.2537, Accuracy: 50.5618%, Time: 0.3834s
# Best Accuracy for validation : 0.5056 at epoch 008
# Accuracy: 0.505618 classID:1 acc:0.897959  classID:2 acc:0.550000  classID:3 acc:0.538462  classID:4 acc:0.000000
# Epoch: 9/100
# Epoch: 009, Training: Loss: 1.1298, Accuracy: 50.4854%,
# 		Validation: Loss: 1.2224, Accuracy: 56.1798%, Time: 0.3837s
# Best Accuracy for validation : 0.5618 at epoch 009
# Accuracy: 0.561798 classID:1 acc:0.918367  classID:2 acc:0.650000  classID:3 acc:0.646154  classID:4 acc:0.000000
# Epoch: 10/100
# Epoch: 010, Training: Loss: 1.1096, Accuracy: 47.5728%,
# 		Validation: Loss: 1.1881, Accuracy: 53.9326%, Time: 0.3835s
# Best Accuracy for validation : 0.5618 at epoch 009
# Accuracy: 0.539326 classID:1 acc:0.877551  classID:2 acc:0.800000  classID:3 acc:0.569231  classID:4 acc:0.000000
# Epoch: 11/100
# Epoch: 011, Training: Loss: 1.0893, Accuracy: 53.3981%,
# 		Validation: Loss: 1.1574, Accuracy: 57.8652%, Time: 0.3936s
# Best Accuracy for validation : 0.5787 at epoch 011
# Accuracy: 0.578652 classID:1 acc:0.897959  classID:2 acc:0.750000  classID:3 acc:0.676923  classID:4 acc:0.000000
# Epoch: 12/100
# Epoch: 012, Training: Loss: 1.0067, Accuracy: 57.2816%,
# 		Validation: Loss: 1.1171, Accuracy: 60.6742%, Time: 0.3849s
# Best Accuracy for validation : 0.6067 at epoch 012
# Accuracy: 0.606742 classID:1 acc:0.938776  classID:2 acc:0.700000  classID:3 acc:0.723077  classID:4 acc:0.022727
# Epoch: 13/100
# Epoch: 013, Training: Loss: 1.0785, Accuracy: 54.3689%,
# 		Validation: Loss: 1.0881, Accuracy: 66.2921%, Time: 0.3835s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.662921 classID:1 acc:0.938776  classID:2 acc:0.700000  classID:3 acc:0.830769  classID:4 acc:0.090909
# Epoch: 14/100
# Epoch: 014, Training: Loss: 1.0127, Accuracy: 54.3689%,
# 		Validation: Loss: 1.1344, Accuracy: 61.7978%, Time: 0.3833s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.617978 classID:1 acc:0.897959  classID:2 acc:0.600000  classID:3 acc:0.815385  classID:4 acc:0.022727
# Epoch: 15/100
# Epoch: 015, Training: Loss: 0.9768, Accuracy: 58.2524%,
# 		Validation: Loss: 1.1447, Accuracy: 60.1124%, Time: 0.3834s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.601124 classID:1 acc:0.775510  classID:2 acc:0.600000  classID:3 acc:0.876923  classID:4 acc:0.000000
# Epoch: 16/100
# Epoch: 016, Training: Loss: 0.9160, Accuracy: 66.9903%,
# 		Validation: Loss: 1.1293, Accuracy: 63.4831%, Time: 0.3836s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.634831 classID:1 acc:0.877551  classID:2 acc:0.700000  classID:3 acc:0.830769  classID:4 acc:0.045455
# Epoch: 17/100
# Epoch: 017, Training: Loss: 0.8636, Accuracy: 70.8738%,
# 		Validation: Loss: 1.0591, Accuracy: 64.6067%, Time: 0.3843s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.646067 classID:1 acc:0.918367  classID:2 acc:0.850000  classID:3 acc:0.784615  classID:4 acc:0.045455
# Epoch: 18/100
# Epoch: 018, Training: Loss: 0.8400, Accuracy: 62.1359%,
# 		Validation: Loss: 1.0390, Accuracy: 61.2360%, Time: 0.3831s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.612360 classID:1 acc:0.938776  classID:2 acc:0.900000  classID:3 acc:0.661538  classID:4 acc:0.045455
# Epoch: 19/100
# Epoch: 019, Training: Loss: 0.7619, Accuracy: 72.8155%,
# 		Validation: Loss: 1.0211, Accuracy: 62.9213%, Time: 0.3837s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.629213 classID:1 acc:0.959184  classID:2 acc:0.850000  classID:3 acc:0.723077  classID:4 acc:0.022727
# Epoch: 20/100
# Epoch: 020, Training: Loss: 0.7441, Accuracy: 70.8738%,
# 		Validation: Loss: 1.0025, Accuracy: 60.6742%, Time: 0.3834s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.606742 classID:1 acc:1.000000  classID:2 acc:0.900000  classID:3 acc:0.615385  classID:4 acc:0.022727
# Epoch: 21/100
# Epoch: 021, Training: Loss: 0.7573, Accuracy: 73.7864%,
# 		Validation: Loss: 0.9447, Accuracy: 61.2360%, Time: 0.3821s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.612360 classID:1 acc:0.938776  classID:2 acc:0.950000  classID:3 acc:0.646154  classID:4 acc:0.045455
# Epoch: 22/100
# Epoch: 022, Training: Loss: 0.7652, Accuracy: 76.6990%,
# 		Validation: Loss: 0.9060, Accuracy: 62.3596%, Time: 0.3832s
# Best Accuracy for validation : 0.6629 at epoch 013
# Accuracy: 0.623596 classID:1 acc:0.938776  classID:2 acc:0.900000  classID:3 acc:0.692308  classID:4 acc:0.045455
# Epoch: 23/100
# Epoch: 023, Training: Loss: 0.6455, Accuracy: 80.5825%,
# 		Validation: Loss: 0.8704, Accuracy: 68.5393%, Time: 0.3822s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.685393 classID:1 acc:0.979592  classID:2 acc:0.900000  classID:3 acc:0.753846  classID:4 acc:0.159091
# Epoch: 24/100
# Epoch: 024, Training: Loss: 0.8123, Accuracy: 66.0194%,
# 		Validation: Loss: 0.8684, Accuracy: 67.4157%, Time: 0.3818s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.674157 classID:1 acc:0.918367  classID:2 acc:0.800000  classID:3 acc:0.784615  classID:4 acc:0.181818
# Epoch: 25/100
# Epoch: 025, Training: Loss: 0.5863, Accuracy: 79.6117%,
# 		Validation: Loss: 0.8987, Accuracy: 68.5393%, Time: 0.3933s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.685393 classID:1 acc:0.938776  classID:2 acc:0.800000  classID:3 acc:0.846154  classID:4 acc:0.113636
# Epoch: 26/100
# Epoch: 026, Training: Loss: 0.5573, Accuracy: 85.4369%,
# 		Validation: Loss: 0.9466, Accuracy: 65.7303%, Time: 0.3838s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.657303 classID:1 acc:0.918367  classID:2 acc:0.900000  classID:3 acc:0.784615  classID:4 acc:0.068182
# Epoch: 27/100
# Epoch: 027, Training: Loss: 0.5819, Accuracy: 81.5534%,
# 		Validation: Loss: 0.9102, Accuracy: 66.8539%, Time: 0.3838s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.668539 classID:1 acc:0.918367  classID:2 acc:0.900000  classID:3 acc:0.800000  classID:4 acc:0.090909
# Epoch: 28/100
# Epoch: 028, Training: Loss: 0.6850, Accuracy: 79.6117%,
# 		Validation: Loss: 0.8927, Accuracy: 65.7303%, Time: 0.3836s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.657303 classID:1 acc:0.877551  classID:2 acc:0.700000  classID:3 acc:0.876923  classID:4 acc:0.068182
# Epoch: 29/100
# Epoch: 029, Training: Loss: 0.5570, Accuracy: 80.5825%,
# 		Validation: Loss: 0.8667, Accuracy: 66.8539%, Time: 0.3832s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.668539 classID:1 acc:0.897959  classID:2 acc:0.750000  classID:3 acc:0.830769  classID:4 acc:0.136364
# Epoch: 30/100
# Epoch: 030, Training: Loss: 0.5092, Accuracy: 82.5243%,
# 		Validation: Loss: 0.7875, Accuracy: 66.8539%, Time: 0.3843s
# Best Accuracy for validation : 0.6854 at epoch 023
# Accuracy: 0.668539 classID:1 acc:0.897959  classID:2 acc:0.900000  classID:3 acc:0.800000  classID:4 acc:0.113636
# Epoch: 31/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f2db6d1bd3d6> in <module>
#      33             labels = labels.long()
#      34
# ---> 35             outputs = my_resnet(inputs)
#      36
#      37             loss = loss_func(outputs, labels)
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torchvision/models/resnet.py in forward(self, x)
#     218
#     219     def forward(self, x):
# --> 220         return self._forward_impl(x)
#     221
#     222
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     213         x = self.avgpool(x)
#     214         x = torch.flatten(x, 1)
# --> 215         x = self.fc(x)
#     216
#     217         return x
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/nn/modules/dropout.py in forward(self, input)
#      52
#      53     def forward(self, input):
# ---> 54         return F.dropout(input, self.p, self.training, self.inplace)
#      55
#      56
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/nn/functional.py in dropout(input, p, training, inplace)
#     934     return (_VF.dropout_(input, p, training)
#     935             if inplace
# --> 936             else _VF.dropout(input, p, training))
#     937
#     938
#
# ~/anaconda3/envs/dong/lib/python3.6/site-packages/torch/_VF.py in __getattr__(self, attr)
#       9         self.vf = torch._C._VariableFunctions
#      10
# ---> 11     def __getattr__(self, attr):
#      12         return getattr(self.vf, attr)
#      13
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 3)
plt.show()
 
plt.plot(history[:, 2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.show()
